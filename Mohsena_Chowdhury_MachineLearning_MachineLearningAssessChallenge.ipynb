# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import sklearn

# %%
df_job_skills = pd.read_csv('job_skills.csv')

# %%
df_job_skills.head()
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
# 3  Google            Developer Advocate, Partner Engineering
# 4  Google     Program Manager, Audio Visual (AV) Deployments
#
#                        Category                          Location  \
# 0            Program Management                         Singapore
# 1  Manufacturing & Supply Chain                   Shanghai, China
# 2           Technical Solutions       New York, NY, United States
# 3           Developer Relations  Mountain View, CA, United States
# 4            Program Management      Sunnyvale, CA, United States
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
# 1  Drive cross-functional activities in the suppl...
# ...

# %%
df_job_skills.describe()
# Out:
#        Company                 Title                    Category  \
# count     1250                  1250                        1250
# unique       2                   794                          23
# top     Google  Business Intern 2018  Sales & Account Management
# freq      1227                    35                         168
#
#                                 Location  \
# count                               1250
# unique                                92
# top     Mountain View, CA, United States
# freq                                 190
#
#                                          Responsibilities  \
# count                                                1235
# unique                                                801
# top     Responsibilities and detailed projects will be...
# freq                                                   33
#
#                                    Minimum Qualifications  \
# count                                                1236
# ...

# %%
df_job_skills["Category"].value_counts()
# Out:
# Sales & Account Management          168
# Marketing & Communications          165
# Finance                             115
# Technical Solutions                 101
# Business Strategy                    98
# People Operations                    86
# User Experience & Design             84
# Program Management                   74
# Partnerships                         60
# Product & Customer Support           50
# Legal & Government Relations         46
# Administrative                       40
# Sales Operations                     31
# Software Engineering                 31
# Hardware Engineering                 26
# Real Estate & Workplace Services     25
# Manufacturing & Supply Chain         16
# Technical Infrastructure             11
# Network Engineering                   6
# IT & Data Management                  5
# Developer Relations                   5
# Technical Writing                     5
# Data Center & Network                 2
# Name: Category, dtype: int64

# %%
df_job_skills["Category"].value_counts().to_frame().plot.bar(color='r')

# %%
df_job_skills["Location"].value_counts().to_frame().plot.bar(color='r',figsize=(15, 6))

# %%
df_pivot_table = pd.pivot_table(df_job_skills, values='Category', index=['Company','Title'], aggfunc='first')
df_pivot_table
# Out:
#                                                                                     Category
# Company Title
# Google  APAC Accounting Lead, Non-Ads Products                                       Finance
#         APAC Manager, Employment Tax                                                 Finance
#         APAC SMB Account Manager, Google Cloud (Mandari...        Sales & Account Management
#         AR and VR Writer                                          Marketing & Communications
#         ASIC Physical Design Engineering Tech Lead & Ma...              Hardware Engineering
# ...                                                                                      ...
# YouTube Quality Program Manager, Global Vendor Operatio...        Product & Customer Support
#         Real Estate and Workplace Services (REWS) Busin...  Real Estate & Workplace Services
#         Residual Manager, YouTube Originals                                          Finance
# ...

# %%
df_pivot_table = pd.pivot_table(df_job_skills, values='Location', index=['Category'], aggfunc=np.sum)
df_pivot_table
# Out:
#                                                                            Location
# Category
# Administrative                    Xinyi District, TaiwanSingaporeBeijing, ChinaB...
# Business Strategy                 Mountain View, CA, United StatesSan Bruno, CA,...
# Data Center & Network             Sunnyvale, CA, United StatesNew York, NY, Unit...
# Developer Relations               Mountain View, CA, United StatesLondon, United...
# Finance                           New York, NY, United StatesNew York, NY, Unite...
# Hardware Engineering              Mountain View, CA, United StatesSouth San Fran...
# IT & Data Management              Zürich, SwitzerlandDublin, IrelandSunnyvale, C...
# Legal & Government Relations      Reston, VA, United StatesParis, FranceMoskva, ...
# Manufacturing & Supply Chain      Shanghai, ChinaXinyi District, TaiwanShanghai,...
# Marketing & Communications        Hyderabad, IndiaMountain View, CA, United Stat...
# ...

# %%
data = pd.read_csv('province_employment_Jan19.csv')
data.head()
# Out:
#                     Province  Population  Labour force  Employment  \
# 0  Newfoundland and Labrador       441.9         262.4       232.5
# 1       Prince Edward Island       126.9          83.7        75.5
# 2                Nova Scotia       803.0         499.2       465.1
# 3              New Brunswick       628.9         386.6       355.0
# 4                     Quebec      7023.3        4544.1      4299.6
#
#    Full-time employment  Part-time employment  Unemployment  \
# 0                 196.5                  36.0          30.0
# 1                  64.3                  11.2           8.3
# 2                 381.6                  83.4          34.2
# 3                 304.2                  50.8          31.6
# 4                3492.1                 807.5         244.5
#
#    Participation rate  Unemployment rate  Employment rate
# 0                59.4               11.4             52.6
# 1                66.0                9.9             59.5
# ...

# %%
data.describe()
# Out:
#          Population  Labour force   Employment  Full-time employment  \
# count     10.000000     10.000000    10.000000             10.000000
# mean    3052.660000   2003.600000  1887.410000           1528.430000
# std     3837.096093   2491.305537  2352.744415           1908.359641
# min      126.900000     83.700000    75.500000             64.300000
# 25%      672.425000    414.750000   382.525000            323.550000
# 50%      959.350000    653.200000   616.950000            499.750000
# 75%     3922.500000   2625.375000  2489.750000           1954.350000
# max    12021.300000   7789.300000  7341.900000           5970.700000
#
#        Part-time employment  Unemployment  Participation rate  \
# count             10.000000     10.000000           10.000000
# mean             358.970000    116.210000           65.180000
# std              445.854538    139.366308            3.533585
# min               11.200000      8.300000           59.400000
# ...

# %%
data = data.fillna(0)
data = data.replace(to_replace='?',value=0)
data.head()
# Out:
#                     Province  Population  Labour force  Employment  \
# 0  Newfoundland and Labrador       441.9         262.4       232.5
# 1       Prince Edward Island       126.9          83.7        75.5
# 2                Nova Scotia       803.0         499.2       465.1
# 3              New Brunswick       628.9         386.6       355.0
# 4                     Quebec      7023.3        4544.1      4299.6
#
#    Full-time employment  Part-time employment  Unemployment  \
# 0                 196.5                  36.0          30.0
# 1                  64.3                  11.2           8.3
# 2                 381.6                  83.4          34.2
# 3                 304.2                  50.8          31.6
# 4                3492.1                 807.5         244.5
#
#    Participation rate  Unemployment rate  Employment rate
# 0                59.4               11.4             52.6
# 1                66.0                9.9             59.5
# ...

# %%
df_table = pd.pivot_table(data, values=['Employment','Unemployment'], index=['Province','Labour force'])
df_table = df_table.sort_values(by=['Employment','Unemployment'], ascending = False)
round(df_table,1)
# Out:
#                                         Employment  Unemployment
# Province                  Labour force
# Ontario                   7789.3            7341.9         447.4
# Quebec                    4544.1            4299.6         244.5
# British Columbia          2668.6            2544.2         124.4
# Alberta                   2495.7            2326.4         169.3
# Manitoba                  696.3              657.7          38.6
# Saskatchewan              610.1              576.2          33.8
# Nova Scotia               499.2              465.1          34.2
# New Brunswick             386.6              355.0          31.6
# Newfoundland and Labrador 262.4              232.5          30.0
# Prince Edward Island      83.7                75.5           8.3

# %%
df_table.plot(kind='bar', figsize=(10,6))
